# %% [markdown]
# <a href="https://colab.research.google.com/github/gafurjanoff/Data_Science_/blob/main/03_PANDAS_yakuniy_vazifa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## Ma'lumotlar tahlili. Pandas kutubxonasi.
#
# ### PANDAS. Yakuniy vazifa. **1-QISM**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/world_population.csv", index_col=0)
df
# Out:
#                country     density   densityMi   pop2021     area
# rank
# 1                Macau  21946.4667  56841.3487   658.394       30
# 2               Monaco  19755.5000  51166.7450    39.511        2
# 3            Singapore   8305.1915  21510.4461  5896.686      710
# 4            Hong Kong   6841.3134  17719.0017  7552.810     1104
# 5            Gibraltar   5616.3333  14546.3033    33.698        6
# ...                ...         ...         ...       ...      ...
# 228            Namibia      3.1338      8.1166  2587.344   825615
# 229     Western Sahara      2.3003      5.9577   611.875   266000
# 230           Mongolia      2.1286      5.5129  3329.289  1564110
# 231   Falkland Islands      0.2902      0.7517     3.533    12173
# 232          Greenland      0.0263      0.0680    56.877  2166086
#
# [232 rows x 5 columns]

# %% [markdown]
# ### 1-VAZIFA. Yuqoridagi DF ustunlari nomini quyidagi qiymatlarga o'zgartiring va DF yuqorisidan 3 ta davlatni chiqaring
# `['davlat','zichlik_km','zichlik_mi','aholi','maydoni']`

# %%
df.rename(columns = {'country' : 'davlat', 'density' : 'zichlik_km','densityMi':'zichlik_mi','pop2021' : 'aholi','area':'maydoni'} , inplace  = True )
df.head(3)

df_new  = df

df_new
# df.columns = ['davlat','zichlik_km','zichlik_mi','aholi','maydoni']
# df.head(3)
# Out:
#                 davlat  zichlik_km  zichlik_mi     aholi  maydoni
# rank
# 1                Macau  21946.4667  56841.3487   658.394       30
# 2               Monaco  19755.5000  51166.7450    39.511        2
# 3            Singapore   8305.1915  21510.4461  5896.686      710
# 4            Hong Kong   6841.3134  17719.0017  7552.810     1104
# 5            Gibraltar   5616.3333  14546.3033    33.698        6
# ...                ...         ...         ...       ...      ...
# 228            Namibia      3.1338      8.1166  2587.344   825615
# 229     Western Sahara      2.3003      5.9577   611.875   266000
# 230           Mongolia      2.1286      5.5129  3329.289  1564110
# 231   Falkland Islands      0.2902      0.7517     3.533    12173
# 232          Greenland      0.0263      0.0680    56.877  2166086
#
# [232 rows x 5 columns]

# %%
#@title To'g'ri javob
df.columns = ['davlat','zichlik_km','zichlik_mi','aholi','maydoni']
df.head(3)
# Out:
#          davlat  zichlik_km  zichlik_mi     aholi  maydoni
# rank
# 1         Macau  21946.4667  56841.3487   658.394       30
# 2        Monaco  19755.5000  51166.7450    39.511        2
# 3     Singapore   8305.1915  21510.4461  5896.686      710

# %% [markdown]
# ## Yuqoridagi jadval dunyo davlatlarining aholi zichligi bo'yicha reytingini ko'rsatadi.
# DF indeksi sifatida davlatning zichlik reytingi olingan (aholi eng zich yashaydigan davlatlar yuqorida).
#
# **Ustunlar:**
#
# `davlat` - Davlat nomi
#
# `zichlik_km` - har 1 kv.km. ga to'g'ri keluvchi aholi soni
#
# `zichlik_mi` - har 1 kv.milyaga to'g'ri keluvchi aholi soni (milya - AQSh masofa o'lchov birligi)
#
# `aholi` - 2021-yilga ko'rsa aholi soni (ming)
#
# `maydoni` - davlat maydoni (kv.km)

# %% [markdown]
# ### 2-VAZIFA. DF oxiridan 10 ta qator chiqaring.

# %%
df.tail(10)
# Out:
#                 davlat  zichlik_km  zichlik_mi      aholi  maydoni
# rank
# 223             Guyana      3.6765      9.5220    790.326   214969
# 224      French Guiana      3.6685      9.5015    306.448    83534
# 225           Suriname      3.6125      9.3564    591.800   163820
# 226          Australia      3.3526      8.6832  25788.215  7692024
# 227            Iceland      3.3335      8.6338    343.353   103000
# 228            Namibia      3.1338      8.1166   2587.344   825615
# 229     Western Sahara      2.3003      5.9577    611.875   266000
# 230           Mongolia      2.1286      5.5129   3329.289  1564110
# 231   Falkland Islands      0.2902      0.7517      3.533    12173
# 232          Greenland      0.0263      0.0680     56.877  2166086

# %% [markdown]
# ### 3-VAZIFA. DF dan 10, 20, 100, 200-indekslarda turgan davlatlarni alohida DF ko'rinishida chiqaring.

# %%
df.iloc[[10,20,100,200]]
# Out:
#           davlat  zichlik_km  zichlik_mi       aholi  maydoni
# rank
# 11    Bangladesh   1126.9465   2918.7915  166303.498   147570
# 21    San Marino    557.6557   1444.3284      34.017       61
# 101        Benin    110.5560    286.3401   12451.040   112622
# 201     Paraguay     17.7495     45.9712    7219.638   406752

# %% [markdown]
# ### 4-VAZIFA. Davlatlar orasida `Uzbekistan`, `Hong-Kong`, `Antartica` borligini tekshiring

# %%
selected_countries = ['Uzbekistan', 'Hong-Kong', 'Antartica']
exist = df[df['davlat'].isin(selected_countries)]

print(exist)
# Out:
#           davlat  zichlik_km  zichlik_mi      aholi  maydoni
# rank
# 133   Uzbekistan     75.8511    196.4542  33935.763   447400

# %% [markdown]
# ### 5-VAZIFA.
# #### 5.1 DFning `davlat` nomli ustunini uning indeksi qilib belgilang.
# #### 5.2 `davlat` ustunini tashlab yuboring.
# #### 5.3 DFni davlat nomi bo'yicha tartiblang

# %%
# 5.1 DFning davlat nomli ustunini uning indeksi qilib belgilang.

df_new.set_index('davlat' , inplace = False)
# Out:
#                   zichlik_km  zichlik_mi     aholi     area
# davlat
# Macau             21946.4667  56841.3487   658.394       30
# Monaco            19755.5000  51166.7450    39.511        2
# Singapore          8305.1915  21510.4461  5896.686      710
# Hong Kong          6841.3134  17719.0017  7552.810     1104
# Gibraltar          5616.3333  14546.3033    33.698        6
# ...                      ...         ...       ...      ...
# Namibia               3.1338      8.1166  2587.344   825615
# Western Sahara        2.3003      5.9577   611.875   266000
# Mongolia              2.1286      5.5129  3329.289  1564110
# Falkland Islands      0.2902      0.7517     3.533    12173
# Greenland             0.0263      0.0680    56.877  2166086
#
# [232 rows x 4 columns]

# %%
# 5.2 davlat ustunini tashlab yuboring.
dropped_data = df.drop(columns = 'davlat')
dropped_data
# Out:
#       zichlik_km  zichlik_mi     aholi  maydoni
# rank
# 1     21946.4667  56841.3487   658.394       30
# 2     19755.5000  51166.7450    39.511        2
# 3      8305.1915  21510.4461  5896.686      710
# 4      6841.3134  17719.0017  7552.810     1104
# 5      5616.3333  14546.3033    33.698        6
# ...          ...         ...       ...      ...
# 228       3.1338      8.1166  2587.344   825615
# 229       2.3003      5.9577   611.875   266000
# 230       2.1286      5.5129  3329.289  1564110
# 231       0.2902      0.7517     3.533    12173
# 232       0.0263      0.0680    56.877  2166086
#
# [232 rows x 4 columns]

# %%
# 5.3 DFni davlat nomi bo'yicha tartiblang
df.sort_values(by = 'davlat')
# Out:
#                  davlat  zichlik_km  zichlik_mi      aholi  maydoni
# rank
# 149         Afghanistan     61.0757    158.1862  39835.428   652230
# 111             Albania     99.9351    258.8318   2872.933    28748
# 198             Algeria     18.7328     48.5179  44616.624  2381741
# 50       American Samoa    276.8844    717.1307     55.100      199
# 78              Andorra    165.2885    428.0971     77.355      468
# ...                 ...         ...         ...        ...      ...
# 131   Wallis and Futuna     78.1268    202.3483     11.094      142
# 229      Western Sahara      2.3003      5.9577    611.875   266000
# 151               Yemen     57.7509    149.5749  30490.640   527968
# 188              Zambia     25.1400     65.1125  18920.651   752612
# 173            Zimbabwe     38.6229    100.0333  15092.171   390757
#
# [232 rows x 5 columns]

# %%
#@title Kutilayotgan natija
# Out:
#                 zichlik_km  zichlik_mi      aholi  maydoni
# davlat
# Afghanistan        61.0757    158.1862  39835.428   652230
# Albania            99.9351    258.8318   2872.933    28748
# Algeria            18.7328     48.5179  44616.624  2381741
# American Samoa    276.8844    717.1307     55.100      199
# Andorra           165.2885    428.0971     77.355      468

# %% [markdown]
# ### 6-VAZIFA. DF dan `Uzbekistan`, `Malaysia`, `South Korea`, `France` davlatlari `aholi` va `maydoni` ustunlari bilan alohida DF ko'rinishida ajratib oling.

# %%
df_selct = ['Uzbekistan', 'Malaysia', 'South' 'Korea', 'France']
df_sel = ['aholi' , 'maydoni']

selected_rows = df_new.loc[df['davlat'].isin(df_selct)]

result = selected_rows[df_sel]
result
# Out:
#           aholi  maydoni
# rank
# 95    65426.179   551695
# 113   32776.194   330803
# 133   33935.763   447400

# %%
#@title O'xshash natija (boshqa davlatlar uchun)
# Out:
#                  aholi  maydoni
# davlat
# Singapore     5896.686      710
# North Korea  25887.041   120538
# Germany      83900.473   357114
# Kazakhstan   18994.962  2724900

# %% [markdown]
# ### 7-VAZIFA. Asl DFning `aholi` ustuni qiymatlarini 1000 ga ko'paytiring.

# %%
df[df_new['aholi'] * 1000]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-00e5e4bb765f> in <cell line: 1>()
# ----> 1 df[[df_new['aholi'] * 1000]]
#       2
#       3
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3765             if is_iterator(key):
#    3766                 key = list(key)
# -> 3767             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768
#    3769         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5875             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5876
# -> 5877         self._raise_if_missing(keyarr, indexer, axis_name)
#    5878
#    5879         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5936                 if use_interval_msg:
#    5937                     key = list(key)
# -> 5938                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5939
#    5940             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index([(658394.0, 39511.0, 5896686.0, 7552810.0, 33698.0, 1748296.0, 543617.0, 442784.0, 43412.0, 62090.0, 166303498.0, 5222748.0, 800.0, 279515.0, 39234.0, 287711.0, 23855010.0, 6769146.0, 1273433.0, 107204.0, 34017.0, 10876.0, 51305186.0, 13276513.0, 888451.0, 9907.0, 11931.0, 12255433.0, 1393409038.0, 8789774.0, 11541685.0, 17173099.0, 11632326.0, 164798.0, 901686.0, 126050804.0, 374745.0, 59610.0, 113021.0, 21497310.0, 111046913.0, 2828255.0, 170179.0, 6518499.0, 104226.0, 184400.0, 98168833.0, 111263.0, 68207116.0, 55100.0, 1403375.0, 2973463.0, 225199937.0, 2930528.0, 66497.0, 400020.0, 634814.0, 4328550.0, 38250.0, 83900473.0, 2486945.0, 223368.0, 211400708.0, 10953703.0, 98731.0, 98908.0, 25887041.0, 8715494.0, 53544.0, 29674920.0, 30421.0, 60367477.0, 47123531.0, 18249860.0, 15117.0, 19647684.0, 116254.0, 77355.0, 121392.0, 85410.0, 8478250.0, 1444216107.0, 276361783.0, 106760.0, 561898.0, 69950850.0, 10724555.0, 5813298.0, 31732129.0, 1215584.0, 57917.0, 37797005.0, 9991089.0, 4024019.0, 65426179.0, 10223342.0, 10269021.0, 1373.0, 8141343.0, 5460721.0, ...)], dtype='object')] are in the [columns]"

# %%
#@title Kutilgan natija
# Out:
#                 zichlik_km  zichlik_mi       aholi  maydoni
# davlat
# Afghanistan        61.0757    158.1862  39835428.0   652230
# Albania            99.9351    258.8318   2872933.0    28748
# Algeria            18.7328     48.5179  44616624.0  2381741
# American Samoa    276.8844    717.1307     55100.0      199
# Andorra           165.2885    428.0971     77355.0      468

# %% [markdown]
# DF ni `aholi` ustuni bo'yicha kamayish tartibida tahlang va aholisi eng kam 10 ta davlatni chiqaring.

# %%
df_new_sorted = df_new.sort_values(by='aholi', ascending=False)

df_new_sorted.head(10)
# Out:
#              davlat  zichlik_km  zichlik_mi        aholi   maydoni  \
# rank
# 82            China    148.7815    385.3441  1444216.107   9706961
# 29            India    423.8391   1097.7432  1393409.038   3287590
# 174   United States     35.5200     91.9968   332915.073   9372610
# 83        Indonesia    145.1046    375.8210   276361.783   1904569
# 53         Pakistan    255.3542    661.3674   225199.937    881912
# 189          Brazil     25.1291     65.0843   213993.437   8515767
# 63          Nigeria    228.8461    592.7114   211400.708    923768
# 11       Bangladesh   1126.9465   2918.7915   166303.498    147570
# 214          Russia      8.5337     22.1024   145912.025  17098242
# 144          Mexico     66.3123    171.7488   130262.216   1964375
#
#       aholi_in_thousands
# rank
# 82          1.444216e+09
# 29          1.393409e+09
# 174         3.329151e+08
# 83          2.763618e+08
# 53          2.251999e+08
# 189         2.139934e+08
# 63          2.114007e+08
# 11          1.663035e+08
# 214         1.459120e+08
# 144         1.302622e+08

# %%
# df_min = df_new.loc[[df_new['aholi'].idxmin()]]

df_new_sorted = df.sort_values(by='aholi', ascending=True)

df_new_sorted.head(10)
# Out:
#                          davlat  zichlik_km  zichlik_mi   aholi  maydoni  \
# rank
# 13                 Vatican City    800.0000   2072.0000   0.800        1
# 98                      Tokelau    114.4167    296.3392   1.373       12
# 218                        Niue      6.2269     16.1277   1.619      260
# 231            Falkland Islands      0.2902      0.7517   3.533    12173
# 161                  Montserrat     48.7941    126.3768   4.977      102
# 191   Saint Pierre and Miquelon     23.8264     61.7105   5.766      242
# 26             Saint Barthelemy    471.7619   1221.8633   9.907       21
# 22                        Nauru    517.9048   1341.3733  10.876       21
# 131           Wallis and Futuna     78.1268    202.3483  11.094      142
# 27                       Tuvalu    458.8846   1188.5112  11.931       26
#
#       aholi_in_thousands
# rank
# 13                 800.0
# 98                1373.0
# 218               1619.0
# 231               3533.0
# 161               4977.0
# 191               5766.0
# 26                9907.0
# 22               10876.0
# 131              11094.0
# 27               11931.0

# %% [markdown]
# ### 8-VAZIFA. DFni `maydoni` bo'yicha reytinglang (rank) va reytinglarni yangi `rank` ustuniga yozing.

# %%
df_new['rank'] = df['maydoni'].rank()
df_new
# Out:
#                 davlat  zichlik_km  zichlik_mi     aholi  maydoni  \
# rank
# 1                Macau  21946.4667  56841.3487   658.394       30
# 2               Monaco  19755.5000  51166.7450    39.511        2
# 3            Singapore   8305.1915  21510.4461  5896.686      710
# 4            Hong Kong   6841.3134  17719.0017  7552.810     1104
# 5            Gibraltar   5616.3333  14546.3033    33.698        6
# ...                ...         ...         ...       ...      ...
# 228            Namibia      3.1338      8.1166  2587.344   825615
# 229     Western Sahara      2.3003      5.9577   611.875   266000
# 230           Mongolia      2.1286      5.5129  3329.289  1564110
# 231   Falkland Islands      0.2902      0.7517     3.533    12173
# 232          Greenland      0.0263      0.0680    56.877  2166086
#
#       aholi_in_thousands   rank
# rank
# 1               658394.0    8.0
# 2                39511.0    2.0
# 3              5896686.0   43.0
# 4              7552810.0   50.0
# 5                33698.0    3.0
# ...                  ...    ...
# 228            2587344.0  198.0
# 229             611875.0  155.0
# 230            3329289.0  214.0
# 231               3533.0   70.0
# 232              56877.0  221.0
#
# [232 rows x 7 columns]

# %%
#@title Kutilgan natija
# Out:
#                    zichlik_km  zichlik_mi       aholi  maydoni   rank
# davlat
# Afghanistan           61.0757    158.1862  39835428.0   652230  192.0
# Albania               99.9351    258.8318   2872933.0    28748   89.0
# Algeria               18.7328     48.5179  44616624.0  2381741  223.0
# American Samoa       276.8844    717.1307     55100.0      199   20.0
# Andorra              165.2885    428.0971     77355.0      468   38.0
# ...                       ...         ...         ...      ...    ...
# Wallis and Futuna     78.1268    202.3483     11094.0      142   15.0
# Western Sahara         2.3003      5.9577    611875.0   266000  155.0
# Yemen                 57.7509    149.5749  30490640.0   527968  183.0
# Zambia                25.1400     65.1125  18920651.0   752612  194.0
# Zimbabwe              38.6229    100.0333  15092171.0   390757  172.0
#
# [232 rows x 5 columns]

# %% [markdown]
# #### `Uzbekistan`, `United Kingdom`, `Indonesia` davlatlari alohida df ko'rinishida chiqaring

# %%
selected_cs = ['Uzbekistan', 'United Kingdom', 'Indonesia']

df2 = df_new[df_new['davlat'].isin(selected_cs)]

df2.set_index('davlat')
# Out:
#                 zichlik_km  zichlik_mi       aholi  maydoni  \
# davlat
# United Kingdom    280.8033    727.2805   68207.116   242900
# Indonesia         145.1046    375.8210  276361.783  1904569
# Uzbekistan         75.8511    196.4542   33935.763   447400
#
#                 aholi_in_thousands   rank
# davlat
# United Kingdom          68207116.0  153.0
# Indonesia              276361783.0  218.0
# Uzbekistan              33935763.0  176.0

# %%
#@title O'xshash natija (boshqa davlatlar uchun)
# Out:
#                zichlik_km  zichlik_mi        aholi  maydoni   rank
# davlat
# Turkmenistan      12.5342     32.4635    6117924.0   488100  180.0
# United States     35.5200     91.9968  332915073.0  9372610  229.0
# Vietnam          296.3927    767.6572   98168833.0   331212  166.0

# %% [markdown]
# ### 9-VAZIFA. DFni `davlat` nomi bo'yicha tartiblang.

# %%
df_new.sort_values(by = 'davlat')
# Out:
#                  davlat  zichlik_km  zichlik_mi      aholi  maydoni  \
# rank
# 149         Afghanistan     61.0757    158.1862  39835.428   652230
# 111             Albania     99.9351    258.8318   2872.933    28748
# 198             Algeria     18.7328     48.5179  44616.624  2381741
# 50       American Samoa    276.8844    717.1307     55.100      199
# 78              Andorra    165.2885    428.0971     77.355      468
# ...                 ...         ...         ...        ...      ...
# 131   Wallis and Futuna     78.1268    202.3483     11.094      142
# 229      Western Sahara      2.3003      5.9577    611.875   266000
# 151               Yemen     57.7509    149.5749  30490.640   527968
# 188              Zambia     25.1400     65.1125  18920.651   752612
# 173            Zimbabwe     38.6229    100.0333  15092.171   390757
#
#       aholi_in_thousands   rank
# rank
# 149           39835428.0  192.0
# 111            2872933.0   89.0
# 198           44616624.0  223.0
# 50               55100.0   20.0
# 78               77355.0   38.0
# ...                  ...    ...
# 131              11094.0   15.0
# 229             611875.0  155.0
# 151           30490640.0  183.0
# 188           18920651.0  194.0
# 173           15092171.0  172.0
#
# [232 rows x 7 columns]

# %%
#@title Kutilgan natija
# Out:
#                 zichlik_km  zichlik_mi       aholi  maydoni   rank
# davlat
# Afghanistan        61.0757    158.1862  39835428.0   652230  192.0
# Albania            99.9351    258.8318   2872933.0    28748   89.0
# Algeria            18.7328     48.5179  44616624.0  2381741  223.0
# American Samoa    276.8844    717.1307     55100.0      199   20.0
# Andorra           165.2885    428.0971     77355.0      468   38.0

# %% [markdown]
# #### DFdan 10,50,100,200-o'rinda turgan davlatlarni alohida DF ko'rinishida chiqaring

# %%
df_new.loc[[10,50,100,200]]
# Out:
#               davlat  zichlik_km  zichlik_mi     aholi  maydoni  \
# rank
# 10           Bermuda   1149.8148   2978.0204    62.090       54
# 50    American Samoa    276.8844    717.1307    55.100      199
# 100         Slovakia    111.3592    288.4203  5460.721    49037
# 200      New Zealand     17.9713     46.5457  4860.643   270467
#
#       aholi_in_thousands   rank
# rank
# 10               62090.0   11.0
# 50               55100.0   20.0
# 100            5460721.0  103.0
# 200            4860643.0  157.0

# %%
#@title O'xshash natija (boshqa qatorlar uchun)
# Out:
#                               zichlik_km  zichlik_mi     aholi  maydoni  rank
# davlat
# Belize                           17.6310     45.6643  404914.0    22966  82.0
# French Polynesia                 67.8018    175.6066  282530.0     4167  60.0
# Guadeloupe                      245.7125    636.3955  400020.0     1628  53.0
# United States Virgin Islands    300.3631    777.9405  104226.0      347  29.0

# %% [markdown]
# ### 10-VAZIFA. Quyidagi davlatlarning `aholi` sonini oddiy son ko'rinishida chiqaring:
# - `Malaysia`
# - `Nigeria`
# - `Nepal`
# - `Italy`

# %%
countries = ['Malaysia' ,  'Nigeria' , 'Nepal' , 'Italy']

sumpo_cs  = df_new[df_new['davlat'].isin(countries)]
np.sum(sumpo_cs.aholi)
# Out:
# 334219.29900000006

# %%
#@title o'xshash natija (`Uzbekistan` uchun)
# Out:
# 33935763.0
